# %%
import numpy as np

# %%
m = np.random.rand(20,4)

# %%
keys = list(range(12))
# ensemble = dict(zip(keys, [None]*len(keys)))
# ensemble2 = {k:[] for k in keys}
ensemble = dict.fromkeys(keys)

# %%
ensemble
# Out:
# {0: None,
#  1: None,
#  2: None,
#  3: None,
#  4: None,
#  5: None,
#  6: None,
#  7: None,
#  8: None,
#  9: None,
#  10: None,
#  11: None}

# %%
m
# Out:
# array([[0.70560896, 0.26673899, 0.99937133, 0.61150463],
#        [0.60891526, 0.51568722, 0.81333401, 0.02253777],
#        [0.02093188, 0.09289172, 0.73405039, 0.59207454],
#        [0.30350122, 0.64214253, 0.52519489, 0.41978178],
#        [0.54968048, 0.28843705, 0.51951488, 0.89084001],
#        [0.14780438, 0.17032426, 0.50202419, 0.2128132 ],
#        [0.35924858, 0.99320204, 0.64607247, 0.67394719],
#        [0.7819038 , 0.6847704 , 0.3520998 , 0.44790982],
#        [0.4477    , 0.61087622, 0.91953351, 0.84852612],
#        [0.80250865, 0.27564615, 0.27337588, 0.95069003],
#        [0.63638116, 0.70746268, 0.80370813, 0.0633761 ],
#        [0.02530816, 0.52967607, 0.94774801, 0.71733961],
#        [0.33162484, 0.38516708, 0.48061619, 0.98760889],
#        [0.13547754, 0.12528864, 0.47623202, 0.20260492],
#        [0.49570919, 0.18324122, 0.35648774, 0.07395276],
#        [0.44958312, 0.67112589, 0.01064617, 0.60587993],
# ...

# %%
x = np.random.rand(120,20)

# %%
p = x.dot(m)

# %%
p
# Out:
# array([[4.55883052, 4.74222341, 4.86856676, 5.39005654],
#        [5.68009706, 5.25370307, 5.91777708, 6.48649118],
#        [4.30868197, 3.47687915, 4.14107241, 4.25143011],
#        [4.24475903, 4.14221289, 4.29849642, 5.42721624],
#        [4.8930154 , 5.35079147, 6.44285524, 5.08935224],
#        [5.71842053, 5.4851536 , 5.97069323, 5.47294558],
#        [4.31604231, 4.23475873, 4.73383208, 4.42838822],
#        [4.71729021, 4.13554285, 5.14770195, 4.23175263],
#        [4.95654784, 4.7941515 , 5.09784839, 5.02821887],
#        [4.60386773, 4.34977045, 4.97709092, 4.48810798],
#        [4.12386602, 4.28497585, 4.43993175, 5.00655556],
#        [5.02005516, 3.81850944, 4.79811199, 4.16103543],
#        [5.06214753, 4.4124342 , 4.78399633, 4.56630206],
#        [3.604095  , 4.58110704, 4.66506802, 4.88604671],
#        [4.57081365, 4.04088154, 4.26270357, 4.06227275],
#        [5.54317155, 5.7402787 , 6.55621545, 5.87063334],
# ...

# %%
class ELM(object):
    def init_weights(self,c,h):
         return np.random.rand(c,h)
    def insert_bias(self,m):
        return m
    def pinv(self,m):
        return np.linalg.pinv(m)

# %%
elm  = ELM()

# %%
 wh = elm.init_weights(1,1)

# %%
elm.pinv(wh)
# Out:
# array([[59.3049451]])

# %%
ensemble[0] = elm

# %%
ensemble

# %%
a = [[1,2,3],[2,4,7],[9,8,5]]
from util import *

# %%
addBias(a)
